# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dat=np.load("lc.npz")

# %%
t,lc=dat["arr_0"]
tx,lcx=dat["arr_1"]

# %%
plt.plot(t,lc,".",alpha=0.2)
plt.plot(tx,lcx,"s")
plt.ylim(0.98,1.005)
plt.xlabel("Time [min]")
plt.savefig("pers10.png")
